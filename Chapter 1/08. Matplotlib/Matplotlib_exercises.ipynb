# %% [markdown]
# # Matplotlib

# %% [markdown]
# For these exercises, we are using Pandas and Matplotlib to visualize Company Sales Data.
#
# We will be using the following dataset: https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv

# %% [markdown]
# ### Exercise 1: Read the Total profit of all months and show it using a line plot.
# Total profit data provided for each month. The enerated line plot must include the following properties:<br>
# - X label name = Month Number
# - Y label name = Total profit
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from imp import reload

# %%
reload(plt)
data_filepath = 'company_sales_data.csv'
data = pd.read_csv(data_filepath)
x = data['month_number']
y = data['total_profit']

plt.figure(figsize=(15,12))
plt.xlabel('Month Number')
plt.ylabel('Sold units number')
plt.plot(x,y)
plt.ylabel('Total profit')
plt.xlabel('Month Number')
plt.title('Company profit per month',fontdict={'fontsize':25})
plt.xlabel('Month Number',fontsize=20)
plt.ylabel('Sold units number',fontsize=20)

plt.show()

# %% [markdown]
# ### Exercise 2: Get the Total profit of all months and show a line plot with the following Style properties:
# - Line Style dotted and Line color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(12,6))
plt.plot(x,y,'r--',linewidth=3.0,label='Total Profit')
plt.plot(x,y,'go',linewidth=3.0,label='Total sold units')   # I did the circles green instead of red because it's easier to see
plt.title('Company Sales data of last year',fontdict={'fontsize':25})
plt.xlabel('Month Number',fontsize=20)
plt.ylabel('Sold units number',fontsize=20)
plt.legend(loc='lower right')

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it using a multiline plot.
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
plt.figure(figsize=(12,6))
plt.plot(x,data['facewash'],label='facewash')
plt.plot(x,data['toothpaste'],label='toothpaste')
plt.plot(x,data['bathingsoap'],label='bathingsoap')
plt.plot(x,data['moisturizer'],label='moisturizer')
plt.plot(x,data['facecream'],label='facecream')
plt.title('Sales Data',fontdict={'fontsize':25})
plt.ylabel('Sales units in number',fontsize=20)
plt.xlabel('Month in number',fontsize=20)
plt.legend()

# %% [markdown]
# ### Exercise 4: Read the toothpaste sales data of each month and show it using a scatter plot.
# Also, add a grid in the plot (the grid line style should be “–“).
#
# The scatter plot should look like this:
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(12,6))
plt.scatter(x,data['toothpaste'])
plt.grid(True,ls='--')
plt.title('Toothpaste Sales Data',fontdict={'fontsize':25})
plt.ylabel('Number of Units Sold',fontsize=20)
plt.xlabel('Month Number',fontsize=20)

plt.show()

# %% [markdown]
# ### Exercise 5: Read the face cream and facewash product sales data and show it using the bar chart.
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(12,6))
plt.bar(x-.2,data['facecream'],width=.4,label='Facecream sales')
plt.bar(x+.2,data['facewash'],width=.4,label='Facewash sales')
plt.title('Face Wash and Face Cream Sales Data',fontdict={'fontsize':25})
plt.ylabel('Sales units in number',fontsize=20)
plt.xlabel('Month Number',fontsize=20)
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# ### Exercise 6: Read the sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(10,6))
plt.bar(x,data['bathingsoap'])
plt.grid(True,ls='--')
plt.title('Bathing Soap Sales Data',fontdict={'fontsize':25})
plt.savefig('bathing_sales_data.png')
plt.ylabel('Sales units in number',fontsize=20)
plt.xlabel('Month Number',fontsize=20)

plt.show()

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges.
# The histogram should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
plt.figure(figsize=(14,10))
plt.hist(data['total_profit'])
plt.ylabel('Actual Profit in dollar',fontsize=20)
plt.xlabel('profit range in dollar',fontsize=20)
plt.title('Profit Data',fontdict={'fontsize':25})
plt.show()

# %% [markdown]
# ### Exercise 8: Calculate the total sale data for last year for each product and show it using a Pie chart.
# Note: In the Pie chart you should display the Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this:
# ![image.png](attachment:image.png)

# %%
labels = ['Face Cream','Face Wash','Toothpaste','Bathing Soap','Shampoo','Moisturizer']
values = [data['facecream'].sum(),data['facewash'].sum(),data['toothpaste'].sum(),data['bathingsoap'].sum(),data['shampoo'].sum(),data['moisturizer'].sum()]

plt.figure(figsize=(14,10))
plt.pie(values, labels=labels,autopct='%1.1f%%',textprops={'fontsize':14})
plt.legend(loc='lower right')
plt.title('Sales Data',fontdict={'fontsize':25})

plt.show()

# %% [markdown]
# ### Exercise 9: Read the Bathing soap facewash of all months and display it using the Subplot.
# The Subplot should look like this:
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(14,10))

plt.figure(1)   # The first figure
plt.subplot(211)    # the first subplot
plt.plot(x,data['bathingsoap'])
plt.title('Sales data of bathsoap',fontdict={'fontsize':25})
plt.subplot(212)    # next subplot, current subplot under figure 1
plt.plot(x,data['facewash'])
plt.title('Sales data of facewash',fontdict={'fontsize':25})


plt.subplot(211)    #makes subplot(211) in figure1 current
plt.show()

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot.
# The Stack plot should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
labels = ['Face Cream','Face Wash','Toothpaste','Bathing Soap','Shampoo','Moisturizer']

plt.figure(figsize=(14,10))
plt.stackplot(data['month_number'],data['facecream'],data['facewash'],data['toothpaste'],data['bathingsoap'],data['shampoo'],data['moisturizer'],labels=labels)
plt.legend(loc='upper left')
plt.title('All product sales data using stack plot',fontdict={'fontsize':25})
plt.ylabel('Sales units in number',fontsize=20)
plt.xlabel('Month Number',fontsize=20)

plt.show()
